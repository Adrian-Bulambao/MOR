# %% [markdown]
# ### this is for making the model on the project

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="gKW93thfJTEiVeFHcd1y")
project = rf.workspace("adrians-workspace-eqzoz").project("mor-qy0wo")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
model = YOLO("yolov8s-seg.pt")

results = model.train(
    data="MOR-1\data.yaml",
    epochs=150,
    imgsz=432,
    batch=8,
    optimizer="AdamW",
    lr0=0.001
)

# %% [markdown]
# Box(P) = 0.948
#
# Box(R) = 0.896
#
# mAP50 = 0.933
#
# mAP50-95 = 0.54
#
# Mask(P) = 0.754
#
# Mask(R) = 0.821
#
# Mask mAP50 = 0.713
#
# Mask mAP50-95 = 0.294

# %%
metrics = model.val()

print(metrics)
# Out:
# Ultralytics 8.4.21  Python-3.10.19 torch-2.12.0.dev20260223+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 16311MiB)
# YOLOv8s-seg summary (fused): 86 layers, 11,779,987 parameters, 0 gradients, 39.9 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 184.829.7 MB/s, size: 7.3 KB)
# val: Scanning C:\Users\JUSTIN\Documents\VS Code\MOR\MOR-1\valid\labels.cache... 25 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 25/25  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.3it/s 1.5s4.2s
#                    all         25         67      0.948      0.896      0.933       0.54      0.754      0.821      0.713      0.294
# Speed: 1.6ms preprocess, 6.3ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to C:\Users\JUSTIN\Documents\VS Code\MOR\runs\segment\val
# ultralytics.utils.metrics.SegmentMetrics object with attributes:
#
# ap_class_index: array([0])
# ...

# %%
from ultralytics import YOLO

model = YOLO(r"runs\segment\train\weights\best.pt")

model(r"MOR-1\test\images\IMG_20260309_160538_206_jpg.rf.04dd3a5c596cc0066f670db53c31c43a.jpg", show=True, conf=0.50, save=True)
# Out:
# image 1/1 c:\Users\JUSTIN\Documents\VS Code\MOR\MOR-1\test\images\IMG_20260309_160538_206_jpg.rf.04dd3a5c596cc0066f670db53c31c43a.jpg: 448x448 2 Impuritys, 28.7ms
# Speed: 2.2ms preprocess, 28.7ms inference, 7.5ms postprocess per image at shape (1, 3, 448, 448)
# Results saved to C:\Users\JUSTIN\Documents\VS Code\MOR\runs\segment\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'Impurity'}
#  obb: None
#  orig_img: array([[[163, 174, 178],
#          [163, 174, 178],
#          [163, 174, 178],
#          ...,
#          [ 87,  86,  82],
#          [ 93,  92,  88],
#          [ 94,  93,  89]],
#
#         [[163, 174, 178],
#          [163, 174, 178],
#          [163, 174, 178],
#          ...,
#          [ 77,  76,  72],
#          [ 75,  74,  70],
#          [ 73,  72,  68]],
#
#         [[163, 174, 178],
# ...
